# %% [markdown]
# # SentinelML Credit Card Fraud EDA
#
# First-pass validation and exploratory analysis for the Kaggle credit card fraud dataset.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.data_pipeline import run_creditcard_eda

# %%
results = run_creditcard_eda(PROJECT_ROOT / "data" / "raw" / "creditcard.csv")

# %% [markdown]
# ## Duplicate Row Examples

# %%
results["duplicate_analysis"]["example_pairs"]
